# %% [markdown]
# <a href="https://colab.research.google.com/github/ROARMarketingConcepts/Data-Analysis-Projects/blob/master/Multiple_Excel_Tabs_Read_in.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
df = pd.read_excel('/gdrive/MyDrive/Colab Notebooks/Audience Quarterly Northern.xlsx',sheet_name=None)

# %%
tab_list = list(df.keys())
tab_list
# Out:
# ['Q2 2024', 'Q3 2024', 'Q4 2024', 'Q1 2025', 'Q2 2025']

# %%
for i in range(len(tab_list)-1):
  df[tab_list[i+1]] = pd.concat([df[tab_list[i+1]],df[tab_list[i]]])

# %%
df1 = df[tab_list[-1]]
df1.head()
# Out:
#    START DATE    END DATE      DAYPART  DESCRIPTION NETWORK MATCH INDEX  0116  \
# 0  2025-03-31  2025-06-29  M-Su 10a-6p          NaN    ACCN     B  NONE   NaN
# 1  2025-03-31  2025-06-29  M-Su 12m-2a          NaN    ACCN     B  NONE   NaN
# 2  2025-03-31  2025-06-29   M-Su 2a-5a          NaN    ACCN     B  NONE   NaN
# 3  2025-03-31  2025-06-29  M-Su 5a-10a          NaN    ACCN     B  NONE   NaN
# 4  2025-03-31  2025-06-29  M-Su 5a-12m          NaN    ACCN     B  NONE   NaN
#
#    0118  0179  ...  9869  9870  9871  9881  9893  9895  9905  9914  9987  9998
# 0  0.12   NaN  ...   0.3   0.3   0.3   NaN   NaN  0.81   NaN   NaN   NaN   NaN
# 1  0.23   NaN  ...   0.3   0.3   0.3   NaN   NaN  0.23   NaN   NaN   NaN   NaN
# 2  0.35   NaN  ...   0.3   0.3   0.3   NaN   NaN  0.35   NaN   NaN   NaN   NaN
# 3  0.12   NaN  ...   0.3   0.3   0.3   NaN   NaN  0.58   NaN   NaN   NaN   NaN
# 4  0.23   NaN  ...   0.3   0.4   0.4   NaN   NaN  0.81   NaN   NaN   NaN   NaN
#
# [5 rows x 177 columns]

# %%
df1['START DATE'].max()
# Out:
# '2025-03-31'
